# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
df =  pd.read_csv("subway1.csv")

# %%
df
# Out:
#          date  line           station  ridepan_n  offpan_n  ele_n  lift_n  \
# 0    20220511     3          ��������       9795      9712    3.0     NaN
# 1    20220511     8          ��������       8187      9157    3.0     NaN
# 2    20220511     7      ��������д���      48308     48771    3.0     NaN
# 3    20220511     2              ����      88738     88348    2.0     1.0
# 4    20220511     7           ������û      17695     19647    2.0     NaN
# ..        ...   ...               ...        ...       ...    ...     ...
# 268  20220511     3               ȫ��      19501     18490    2.0     NaN
# 269  20220511     5               ȭ��      30718     28395    1.0     NaN
# 270  20220511     6  ȭ����(���￩���Ա�)      14056     10800    2.0     NaN
# 271  20220511     4     ȸ��(���빮����)      27451     29228    3.0     NaN
# 272  20220511     6          ȿâ������       8186      7486    1.0     NaN
#
#      trans_n  5h30m    6h  ...  trainreserve_  issuer_  kiosk_  nursing_  \
# ...

# %%
In = {'Y': 1, 'N':0 }

# %%
df.columns
# Out:
# Index(['date', 'line', 'station', 'ridepan_n', 'offpan_n', 'ele_n', 'lift_n',
#        'trans_n', '5h30m', '6h', '6h30m', '7h', '7h30m', '8h', '8h30m', '9h',
#        '9h30m', '10h', '10h30m', '11h', '11h30m', '12h', '12h30m', '13h',
#        '13h30m', '14h', '14h30m', '15h', '15h30m', '16h', '16h30m', '17h',
#        '17h30m', '18h', '18h30m', '19h', '19h30m', '20h', '20h30m', '21h',
#        '21h30m', '22h', '22h30m', '23h', '23h30m', '24h', '24h30m', 'finedust',
#        'co2', 'hcho', 'co', 'culture_', 'lift_', 'meeting_', 'transspace_',
#        'biycle_', 'ele_', 'trainreserve_', 'issuer_', 'kiosk_', 'nursing_',
#        'address', 'temp', 'wind', 'rain', 'popluation', 'cluster'],
#       dtype='object')

# %%
df['ele_'] = df['ele_'].map(In)

# %%
df['ele_']
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 268    1.0
# 269    1.0
# 270    1.0
# 271    1.0
# 272    1.0
# Name: ele_, Length: 273, dtype: float64

# %%
df['culture_'] = df['culture_'].map(In)
df['lift_'] = df['lift_'].map(In)
df['meeting_'] = df['meeting_'].map(In)
df['transspace_'] = df['transspace_'].map(In)
df['biycle_'] = df['biycle_'].map(In)
df['trainreserve_'] = df['trainreserve_'].map(In)
df['issuer_'] = df['issuer_'].map(In)
df['kiosk_'] = df['kiosk_'].map(In)
df['nursing_'] = df['nursing_'].map(In)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 67 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           273 non-null    int64
#  1   line           273 non-null    int64
#  2   station        273 non-null    object
#  3   ridepan_n      273 non-null    int64
#  4   offpan_n       273 non-null    int64
#  5   ele_n          236 non-null    float64
#  6   lift_n         50 non-null     float64
#  7   trans_n        100 non-null    float64
#  8   5h30m          261 non-null    float64
#  9   6h             261 non-null    float64
#  10  6h30m          261 non-null    float64
#  11  7h             261 non-null    float64
#  12  7h30m          261 non-null    float64
#  13  8h             261 non-null    float64
#  14  8h30m          261 non-null    float64
#  15  9h             261 non-null    float64
#  16  9h30m          261 non-null    float64
# ...

# %% [markdown]
# // 결측치가 너무 많은 lift_n, trans_n 제거

# %%
df_sam1 = df.drop(['lift_n','trans_n'],axis=1)

# %%
df_sam1
# Out:
#          date  line           station  ridepan_n  offpan_n  ele_n  5h30m  \
# 0    20220511     3          ��������       9795      9712    3.0   10.5
# 1    20220511     8          ��������       8187      9157    3.0   22.1
# 2    20220511     7      ��������д���      48308     48771    3.0   51.3
# 3    20220511     2              ����      88738     88348    2.0   28.7
# 4    20220511     7           ������û      17695     19647    2.0   12.7
# ..        ...   ...               ...        ...       ...    ...    ...
# 268  20220511     3               ȫ��      19501     18490    2.0   14.5
# 269  20220511     5               ȭ��      30718     28395    1.0   32.3
# 270  20220511     6  ȭ����(���￩���Ա�)      14056     10800    2.0    7.0
# 271  20220511     4     ȸ��(���빮����)      27451     29228    3.0    9.7
# 272  20220511     6          ȿâ������       8186      7486    1.0    7.0
#
#        6h  6h30m    7h  ...  trainreserve_  issuer_  kiosk_  nursing_  \
# ...

# %% [markdown]
# //문자형 데이터 제거

# %%
df_sam1 = df_sam1.drop(['station','address'],axis=1)

# %%
df_sam1
# Out:
#          date  line  ridepan_n  offpan_n  ele_n  5h30m    6h  6h30m    7h  \
# 0    20220511     3       9795      9712    3.0   10.5  17.0   18.0  20.5
# 1    20220511     8       8187      9157    3.0   22.1  23.5   31.9  45.2
# 2    20220511     7      48308     48771    3.0   51.3  34.9   39.4  60.0
# 3    20220511     2      88738     88348    2.0   28.7  18.5   20.4  23.6
# 4    20220511     7      17695     19647    2.0   12.7  30.9   21.4  20.6
# ..        ...   ...        ...       ...    ...    ...   ...    ...   ...
# 268  20220511     3      19501     18490    2.0   14.5  13.3    9.0  11.3
# 269  20220511     5      30718     28395    1.0   32.3  19.4   17.9  25.1
# 270  20220511     6      14056     10800    2.0    7.0   7.8   10.7  19.0
# 271  20220511     4      27451     29228    3.0    9.7  14.4   16.7  19.0
# 272  20220511     6       8186      7486    1.0    7.0   9.8   10.7  13.7
#
#      7h30m  ...  ele_  trainreserve_  issuer_  kiosk_  nursing_  temp  wind  \
# ...

# %% [markdown]
# 인구 수 컬렴 -> population으로 컬럼 명 변경

# %%
df_sam1.rename(columns={'���� �α���':'population'}, inplace = True)

# %%
df_sam1
# Out:
#          date  line  ridepan_n  offpan_n  ele_n  5h30m    6h  6h30m    7h  \
# 0    20220511     3       9795      9712    3.0   10.5  17.0   18.0  20.5
# 1    20220511     8       8187      9157    3.0   22.1  23.5   31.9  45.2
# 2    20220511     7      48308     48771    3.0   51.3  34.9   39.4  60.0
# 3    20220511     2      88738     88348    2.0   28.7  18.5   20.4  23.6
# 4    20220511     7      17695     19647    2.0   12.7  30.9   21.4  20.6
# ..        ...   ...        ...       ...    ...    ...   ...    ...   ...
# 268  20220511     3      19501     18490    2.0   14.5  13.3    9.0  11.3
# 269  20220511     5      30718     28395    1.0   32.3  19.4   17.9  25.1
# 270  20220511     6      14056     10800    2.0    7.0   7.8   10.7  19.0
# 271  20220511     4      27451     29228    3.0    9.7  14.4   16.7  19.0
# 272  20220511     6       8186      7486    1.0    7.0   9.8   10.7  13.7
#
#      7h30m  ...  ele_  trainreserve_  issuer_  kiosk_  nursing_  temp  wind  \
# ...

# %%
data = df_sam1

# %% [markdown]
# popluation 변수 쉼표 제거 및 정수형으로 변환

# %%
data['popluation'] = data['popluation'].replace(',', '', regex=True)

# %%
data['popluation'] = data['popluation'].astype('int')

# %%
data
# Out:
#          date  line  ridepan_n  offpan_n  ele_n  5h30m    6h  6h30m    7h  \
# 0    20220511     3       9795      9712    3.0   10.5  17.0   18.0  20.5
# 1    20220511     8       8187      9157    3.0   22.1  23.5   31.9  45.2
# 2    20220511     7      48308     48771    3.0   51.3  34.9   39.4  60.0
# 3    20220511     2      88738     88348    2.0   28.7  18.5   20.4  23.6
# 4    20220511     7      17695     19647    2.0   12.7  30.9   21.4  20.6
# ..        ...   ...        ...       ...    ...    ...   ...    ...   ...
# 268  20220511     3      19501     18490    2.0   14.5  13.3    9.0  11.3
# 269  20220511     5      30718     28395    1.0   32.3  19.4   17.9  25.1
# 270  20220511     6      14056     10800    2.0    7.0   7.8   10.7  19.0
# 271  20220511     4      27451     29228    3.0    9.7  14.4   16.7  19.0
# 272  20220511     6       8186      7486    1.0    7.0   9.8   10.7  13.7
#
#      7h30m  ...  ele_  trainreserve_  issuer_  kiosk_  nursing_  temp  wind  \
# ...

# %% [markdown]
# fixed된 date변수 제거

# %%
data = data.drop(['date'],axis=1)

# %%
data
# Out:
#      line  ridepan_n  offpan_n  ele_n  5h30m    6h  6h30m    7h  7h30m     8h  \
# 0       3       9795      9712    3.0   10.5  17.0   18.0  20.5   34.2   39.5
# 1       8       8187      9157    3.0   22.1  23.5   31.9  45.2   69.8  106.3
# 2       7      48308     48771    3.0   51.3  34.9   39.4  60.0   80.3  102.6
# 3       2      88738     88348    2.0   28.7  18.5   20.4  23.6   37.2   52.0
# 4       7      17695     19647    2.0   12.7  30.9   21.4  20.6   30.6   43.6
# ..    ...        ...       ...    ...    ...   ...    ...   ...    ...    ...
# 268     3      19501     18490    2.0   14.5  13.3    9.0  11.3   14.0   15.1
# 269     5      30718     28395    1.0   32.3  19.4   17.9  25.1   33.5   42.4
# 270     6      14056     10800    2.0    7.0   7.8   10.7  19.0   31.5   33.8
# 271     4      27451     29228    3.0    9.7  14.4   16.7  19.0   25.6   43.1
# 272     6       8186      7486    1.0    7.0   9.8   10.7  13.7   25.0   41.7
#
# ...

# %%
data.to_csv('2pmdat3.csv')
